# %% [markdown]
# # Object Detection
#
# Hello, this is a very minimal notebook showing a working object detection network using just ~300 lines of modelling and training code. In this lab you will code an object detection with functionality similiar to a Single Shot Detector or YOLO detector.
#
# The first steps would be to understand what anchors are. Anchors are nothing but crops of a specific size and position in the image. The job of our object detector is to classify each anchor as containing an object or not. If the anchor contains an object, we want to find out by how much our anchor needs to change in shape and position to best fit the object in it. (By how much the height, width and center x and y cordinates change.)
#
# Hence, object detection is a multi task network which does classification and regression.
#
#
# The final objective of completing this notebook is to generate some visualizations of the network running on images in the validation set. In addition to this, please upload the weights of your network and share the google drive link. In this notebook below:
#
# https://drive.google.com/file/d/1-RcOMyIHCyIp_8oesbjRSqTOPlHZ5JnQ/view?usp=sharing
#
#
# You should upload the completed notebook to NYU Brightspace.

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/'My Drive'/object_detection/
# %pwd
# %cd /content/drive/'My Drive'/object_detection/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/object_detection
# '/content/drive/My Drive/object_detection'

# %%
# load important modules
# !git clone https://github.com/karanchahal/objectdetection-
# %cd objectdetection-
# Out:
# fatal: destination path 'objectdetection-' already exists and is not an empty directory.
# /content/drive/My Drive/object_detection/objectdetection-

# %%
from extras.shapes_loader import get_shapes_loader
from extras.util import *
import torch
import matplotlib.pyplot as plt
import matplotlib
import torch.nn as nn
from extras.encoder import ResnetEncoder
import torch.nn.functional as F
from extras.anchors import get_offsets
from extras.boxes import box_iou, nms
 
trainloader, valloader = get_shapes_loader(batch_sz=4)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # change this to "cuda" if you have access to a GPU. On CPU, training should take around ~45 mins on CPU.
device = 'cpu'
matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %% [markdown]
# ## Dataset
#
# First let's introduce our dataset. We have a Pytorch dataloader which outputs images and the ground truth data for the bounding boxes. We visualize the dataset below. You dont need to write any code here. However, you should dig into the fun ction that are called to better understand the structure of the dataset.

# %%
sample, target = iter(trainloader).next()
sample = torch.stack(sample,dim=0)

# %%
vis(sample)

# %%
visDet(sample, target)

# %% [markdown]
# ### Target Data for the Dataset
#
# The labels/targets of the datset have 2 types of data for each image.
#
# 1. The bounding boxes which is a tensor of size (N x 4).
# here is N is the number of objects in the image and 4 correspond to:
#
#     a. top left x coordinate
#     b. top left y coordinate
#     c. bottom right x coordinate
#     d. bottom right y coordinate
#
# 2. The second type of targets are the classification labels of size Nx1. Here N corresponds to the number of objects in the image and the 1 corresponds to the label of the object (whether it is a triangle, square or circle).

# %%
print(target[0])
# Out:
# {'bounding_box': tensor([[  0,  20,  42,  62],
#         [ 66,  24, 110,  68],
#         [ 28,  11,  68,  51]]), 'labels': tensor([1, 3, 2], dtype=torch.int32)}

# %% [markdown]
# ### Converting Target Data to Ground Truth
#
# Here we assign bounding boxes to the various anchor boxes in our image. Anchor boxes are rectangular chunks in the image and are spread all across the image. In object detection, we divide the image into a large number of chunks of different sizes and specify two characteristics of that chunk:
#
# 1. Whether it has an object in it or not. This is done by measuring IOU of the chunk with the bounding boxes. If the IOU is > 0.7, we say that the chunk contains the object. If it is less than 0.3, we say the chunk only contains background. If the value is somewhere in between, we say it is a bad chunk and do not use it's contribution to the loss in our backpropogation.
#
# 2. How much should the chunk change in height, width and how much should it translate to best fit the object. These offsets are 4 values, for the height, width, center x and y coordinate. You should use measurements relative to the default anchor position/scale (see below for more details on the anchors).
#
#
# Anchor boxes might be explained best by this image:
# ![Anchor Boxes](https://lilianweng.github.io/lil-log/assets/images/SSD-framework.png)
#
# Now, first we create the chunks or "anchors" for our image. Since our image is 128x 128 in size. In this lab we want to use a stride of 16.  Hence, we should get 192 anchors.
#
#
# ### Why do we get the size 192 ?
#
# We get the size of 192 as we have a total of 192 anchors in an image of 128 x 128 while using a stride of 16 and we have 3 anchors in each position of the image.
#
# Let's break this down.
#
# 128/16 = 8.
#
# Hence, our neural network should output a feature map of 8 x 8 in spatial dimensions. Each grid in this feature map is an anchor position. Each position has 3 boxes/anchors of 3 shapes -> size 40x40, 50x50 and 60x60.
#
# Hence the total anchors are 8x8x3 = 192.
#
# Your first job is to write the code that creates these 192 anchors from an image of size 128x128. Each anchor is represented by the top left and bottom right x,y coordinates of the anchors in regards with a 128x128 image.
#
# Hence, the output of the below function should be a tensor of size [192,4]

# %%
def get_gt_boxes():
    """
    Generate 192 boxes where each box is represented by :
    [top_left_x, top_left_y, bottom_right_x, bottom_right_y]

    Each anchor position should generate 3 boxes according to the scales and ratios given.

    Return this result as a numpy array of size [192,4]
    """
    stride = 16 # The stride of the final feature map is 16 (the model compresses the image from 128 x 128 to 8 x 8)
    map_sz = 128 # this is the length of height/width of the image

    # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    device = 'cpu'
    scales = torch.tensor([40,50,60], device=device)
    ratios = torch.tensor([[1,1]], device=device).view(1,2)
    # TODO

    center_h = (torch.arange(8, device=device)) * stride + stride//2
    center_w = (torch.arange(8, device=device)) * stride + stride//2
    Y, X = torch.meshgrid(center_h, center_w)
    Y, X = Y.reshape(-1), X.reshape(-1)
    anchor_boxes = torch.stack(
            (-scales, -scales, scales, scales)).T.repeat(8*8, 1) / 2
    center_points = torch.stack([X, Y, X, Y],
                            dim=1).repeat_interleave(3, dim=0)
    return center_points + anchor_boxes

gt_boxes = get_gt_boxes()

assert gt_boxes.size() == (192,4)

# %% [markdown]
# # A Pictoral Representation of our Model
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*7heX-no7cdqllky-GwGBfQ.png)
#
#
# However instead of $2k$ in the given image we just have k scores. We group triangles, squares and circles into one foreground class for this demo. Of course, we can have seperate predictions for each class but that is added complexity and is not implemented here.
#
#
# Your next job is to construct the model. Most parts of the model is already constructed, your job is to add the classification and bounding box regression heads to the encoder.

# %%
class ShapesModel(nn.Module):

    def __init__(self):
        super(ShapesModel, self).__init__()

        # for each grid in the feature map we have 3 anchors of sizes: 40x40, 50x50, 60x60
        num_anchors = 3

        # regular resnet 18 encoder
        self.encoder = ResnetEncoder(num_layers=18, pretrained=False)

        # a small conv net
        self.conv = nn.Conv2d(
            256, 256, kernel_size=3, stride=1, padding=1
            )

        # TODO: Add a Convolutional Layer to prediction the class predictions. This is a head that predicts whether a    chunk/anchor contains an object or not.
        # cls_pred.size() == (1, 3, 8, 8)
        self.cls_logits = nn.Conv2d(
            256, 3, kernel_size=3, stride=1, padding=1
            )

        # TODO: Add a Convolutional Layer to prediction the class predictions. This is a  a head that regresses over the 4 bounding box offsets for each anchor
        # box_pred.size() == (1, 12, 8, 8)
        self.bbox_pred = nn.Conv2d(
            256, 12, kernel_size=3, stride=1, padding=1
            )
    
    def permute_and_flatten(self, layer, N, A, C, H, W):
        # helper function that rearranges the input for the loss function
        layer = layer.view(N, -1, C, H, W)
        layer = layer.permute(0, 3, 4, 1, 2) # N, height/y, width/x, anchor, channel
        layer = layer.reshape(N, -1, C) # height*width*anchor_number
        return layer
    
    def get_predict_regressions(self, cls_pred, box_pred):
        # helper function that gets outputs in the right shape for applying the loss
        N, AxC, H, W = cls_pred.shape   # N, anchor*class, height=8, width=8
        Ax4 = box_pred.shape[1]   # N, anchor*4,height=8, width=8
        A = Ax4 // 4
        C = AxC // A
        cls_pred = self.permute_and_flatten(
            cls_pred, N, A, C, H, W
        )
        
        box_pred = self.permute_and_flatten(
            box_pred, N, A, 4, H, W
        )
        return cls_pred, box_pred

    def forward(self, x):
        # x.size() == (1, 3, 128, 128)
        bt_sz = x.size(0)

        # we take the 3rd output feature map of size 8 x 8 from
        # the resnet18 encoder this means that the stride
        # is 16 as our input image is 128x128 in size.
        x = self.encoder(x)[3]    # shape 8*8

        x = F.relu(self.conv(x))
        # x.size() == (1, 256, 8, 8)
        cls_pred = self.cls_logits(x)
        # cls_pred.size() == (1, 3, 8, 8)
        box_pred = self.bbox_pred(x)
        # box_pred.size() == (1, 12, 8, 8)

        cls_pred, box_pred = self.get_predict_regressions(cls_pred, box_pred)
        # cls_pred.size() == (1, 192, 1)
        # box_pred.size() == (1, 192, 4)
        return cls_pred.squeeze(2), box_pred

# %%
m = ShapesModel()
a = torch.randn(1,3,128,128) # dummy input
cls_pred, box_pred = m(a)
print('The outputs of the net are of size: ', cls_pred.size(), box_pred.size())

assert cls_pred.size() == (1,192) and box_pred.size() == (1,192,4)
# Out:
# The outputs of the net are of size:  torch.Size([1, 192]) torch.Size([1, 192, 4])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# Each anchor is represented by the top left and bottom right x,y coordinates of the anchors in regards with a 128x128 image.
#
# Next we have to assign a class label to each anchor and in case the anchor has an IOU > 0.7 with any real object assign 4 offsets to the anchor. We do this for every single image. Each image would have it's own set of anchors with different class probabilities and offsets as that depends on what objects are situated in that image.
#
# Your job is to calculate those values. Fill out the below function. Hint: Use the `box_iou` and `get_offsets` function.

# %%
import numpy as np

def get_bbox_gt(ex_boxes, gt_boxes, sz=128):
    '''
    
    INPUT:
    ex_boxes: [Nx4]: Bounding boxes in the image. Here N is the number of bounding boxes the image has
    gt_boxes: [192 x 4]: Anchor boxes of an image of size 128 x 128 with stride 16. 
    sz : 128
    OUTPUT: 
    gt_classes: [192 x 1] : Class labels for each anchor: 1 is for foreground, 0 is for background and -1 is for a bad anchor. [where IOU is between 0.3 and 0.7]
    gt_offsets: [192 x 4]: Offsets for anchor to best fit the bounding box object. 0 values for 0 and -1 class anchors.

    '''
    high_threshold = 0.7
    low_threshold = 0.3
    
    # TODO
    ex_boxes = ex_boxes.to(device)
    gt_boxes = gt_boxes.to(device)

    # now we compute the miou for each anchor boxes with all ex_boxes, and choose the largest one for next step.
    # print(gt_boxes, ex_boxes)
    miou_list = box_iou(gt_boxes, ex_boxes)
    # size: N*M
    # print(miou_list)
    gt_classes = torch.tensor([1 if max(i)>high_threshold else 0 for i in miou_list], device=device)
    # print(gt_classes)
    # print([-1 if low_threshold< max(i)< high_threshold else 0 for i in miou_list])
    gt_classes += torch.tensor([-1 if low_threshold< max(i)< high_threshold else 0 for i in miou_list], device=device)
    # print(gt_classes)
    if max(gt_classes) < 1:
      ex_boxes_extended = torch.tensor([], device=device)
      gt_boxes_revised  = torch.tensor([], device=device)
      offsets = torch.tensor([], device=device)
    else:
      ex_boxes_extended = torch.stack([ex_boxes[torch.argmax(miou_list[i])] for i in range(len(gt_classes)) if gt_classes[i]==1],
                dim=0)
      # print(ex_boxes_extended.size())
      gt_boxes_revised = torch.stack([gt_boxes[i] for i in range(len(gt_classes)) if gt_classes[i]==1],
                dim=0)
      # print(gt_boxes_revised.size())
      offsets = torch.tensor(get_offsets(gt_boxes_revised, ex_boxes_extended), device=device)
    index_box = torch.tensor([i for i in range(len(gt_classes)) if gt_classes[i]==1], device=device)
    # print(gt_boxes_revised, ex_boxes_extended)

    gt_offsets = torch.tensor([[0]*4]*192, device=device)
    for i in range(len(index_box)):
      gt_offsets[index_box[i]] = offsets[i]
    return gt_classes, gt_offsets

# %%
def get_targets(target, sample):
    '''
    Input
    target => Set of bounding boxes for each image.
    Sample => Each image
    Output:
    Bounding box offsets and class labels for each anchor.
    '''
    batched_preds = []
    batched_offsets = []
    final_cls_targets = []
    final_box_offsets = []
    for t, s in zip(target, sample):
        bboxes = t['bounding_box'].to(device).float()
        class_targets, box_offsets = get_bbox_gt(bboxes, gt_boxes, sz=128)
        final_cls_targets.append(class_targets)
        final_box_offsets.append(box_offsets)
    
    final_cls_targets = torch.stack(final_cls_targets, dim=0)
    final_box_offsets = torch.stack(final_box_offsets, dim=0)

    return final_cls_targets, final_box_offsets

# %%
sample, target = iter(trainloader).next()
sample = torch.stack(sample,dim=0)

class_targets, box_targets = get_targets(target, sample)
print(class_targets.size(), box_targets.size())
# Out:
# torch.Size([4, 192]) torch.Size([4, 192, 4])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# This is the meat of object detection right there ! The correct calculation of the anchors for an image and it's ground truth. Now that this is done, we can move on to our neural network training code.

# %% [markdown]
# ## Loss Function
#
# One more small kink in the puzzle of object detection is the way the classification loss is calculated. Here, the classification loss is the binary cross entropy loss. The loss is calculated only for those anchors which are background and foreground anchors NOT the negative ones.
#
# One more kink in this setup is that we should sample background and foreground anchors in the ratio of 3:1. This is because there are too many background anchors and the model will predict a background anchor for every anchor and still get a 90% accuracy on the classification. To prevent this, we do this sampling which is also called hard online negative sampling. However, as we have a very small amount of anchors here (192) this isn't a problem. However, for smaller strides and different scales and ratios for each position, thie number can balloon to upto 100,000. Hence, implementing hard online negative sampling is left to be optional to you.
#
# For the bounding box regressions, use a Smooth L1 loss, this works well and prevents outliers.
#
# Your next task is to write the code for the class_loss and bbox_loss. The classification loss should be applied to all positive (containing an object) and negative anchors (does not contain an object). The loss should not be calculated for the anchors whose IOU values are between 0.7 and 0.3.
#
# Apply a Smooth L1 loss to regress on the bounding box offsets, (only apply this loss for anchors which contain an object !)
#
# **Extra Credit**: Implement Hard Online Negative Sampling, however it is not necessasary. You can get this model to train without using it as the number of anchors are low for an image in this case.

# %%
# cls_pred.size() == (4, 192, 1)
# box_pred.size() == (4, 192, 4)

def class_loss(out_pred, class_targets, device="cpu"):
    # TODO return class loss
    loss = torch.nn.BCEWithLogitsLoss()
    # mask = torch.tensor([[False if class_targets[j][i] != -1 else True for i in range(anchor)]
    #                      for j in range(batch)], device=device)
    out_pred = out_pred[class_targets != -1]
    class_targets_new = class_targets[class_targets!= -1]
    return loss(out_pred, class_targets_new)


def bbox_loss(out_bbox, box_targets, class_targets):
    # TODO return bounding box offset loss
    anchor = len(out_bbox[0])
    batch = len(out_bbox)
    loss = torch.nn.SmoothL1Loss()
    class_targets = class_targets[:, 0:anchor]
    box_targets = box_targets[:, 0:anchor]
    box_targets = [box_targets[i][j] for j in range(anchor) for i in range(batch) if class_targets[i][j] == 1]
    out_bbox = [out_bbox[i][j] for j in range(anchor) for i in range(batch) if class_targets[i][j] == 1]
    if box_targets == []:
      return loss(torch.tensor([]), torch.tensor([]))
    return loss(torch.stack(out_bbox), torch.stack(box_targets))

# %% [markdown]
# ## Training Function.
#
# This is the training function, you do not need to change any code here. You can add a validation function here to verify that your model is working well. However, you do not need to submit it.

# %%
def train(ep, model, trainloader, optimizer):
        total_loss = 0
        b_loss = 0
        c_loss = 0
        for i, (ims, targets) in enumerate(trainloader):
            ims = torch.stack(list(ims), dim=0).to(device)

            class_targets, box_targets = get_targets(targets, ims)
            out_pred, out_box = model(ims)
            loss_cls = class_loss(out_pred.to(torch.float32), class_targets.to(torch.float32), device=device)
            loss_bbox = bbox_loss(out_box.to(torch.float32), box_targets.to(torch.float32), class_targets.to(torch.float32))
            loss = loss_cls + loss_bbox
            # print(loss)
            if torch.isnan(loss):
                continue
            if loss.item() != 0:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            if (i+1) %50 == 0:
                print('Trained Epoch: {} | Class Loss: {}, Bounding loss: {}'.format(ep, c_loss / i, b_loss / i))
            total_loss += loss.item()
            c_loss += loss_cls.item()
            b_loss += loss_bbox.item()

        avg_c_loss = float(c_loss / len(trainloader))
        avg_b_loss = float(b_loss / len(trainloader))
        print('Trained Epoch: {} | Avg Classification Loss: {}, Bounding loss: {}'.format(ep, avg_c_loss, avg_b_loss))

# %%
model = ShapesModel().to(device)
optimizer = torch.optim.SGD(
        model.parameters(),
        lr=0.1, momentum=0.9, weight_decay=1e-4)    
for ep in range(4):
    train(ep, model, trainloader, optimizer)
    model_file = 'model_' + str(ep+1) + '.pth'
    torch.save(model.state_dict(), model_file)
    print('\nSaved model to ' + model_file + '.')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Trained Epoch: 0 | Class Loss: 0.19471208781612162, Bounding loss: 0.49183287229080097
# Trained Epoch: 0 | Class Loss: 0.1577246833705541, Bounding loss: 0.24422514301933015
# Trained Epoch: 0 | Class Loss: 0.12926578879256376, Bounding loss: 0.16327173414723828
# Trained Epoch: 0 | Class Loss: 0.11192666783217509, Bounding loss: 0.1231117213240729
# Trained Epoch: 0 | Class Loss: 0.1032499972671031, Bounding loss: 0.09913861259866029
# Trained Epoch: 0 | Class Loss: 0.0972595961583797, Bounding loss: 0.08299561499584374
# Trained Epoch: 0 | Class Loss: 0.09259006303647016, Bounding loss: 0.07144644514555576
# Trained Epoch: 0 | Class Loss: 0.08894561466417815, Bounding loss: 0.06283544859633353
# Trained Epoch: 0 | Class Loss: 0.08570115170327486, Bounding loss: 0.0568521656198796
# Trained Epoch: 0 | Class Loss: 0.08497351525213293, Bounding loss: 0.05122489213063287
# Trained Epoch: 0 | Class Loss: 0.08385992766729469, Bounding loss: 0.04679220328013646
# Trained Epoch: 0 | Class Loss: 0.08197271491778713, Bounding loss: 0.0429638507223172
# Trained Epoch: 0 | Class Loss: 0.0801129405012208, Bounding loss: 0.039739462086062514
# Trained Epoch: 0 | Class Loss: 0.07863001999190777, Bounding loss: 0.0370062003574388
# Trained Epoch: 0 | Class Loss: 0.07804258548727978, Bounding loss: 0.03480538076304638
# Trained Epoch: 0 | Class Loss: 0.07761670817365783, Bounding loss: 0.032683354129084095
# Trained Epoch: 0 | Class Loss: 0.076951856752342, Bounding loss: 0.030946340857925938
# Trained Epoch: 0 | Class Loss: 0.07619670854759163, Bounding loss: 0.029298966434353844
# Trained Epoch: 0 | Class Loss: 0.07579808999382909, Bounding loss: 0.028059145115681777
# Trained Epoch: 0 | Class Loss: 0.0753060837236193, Bounding loss: 0.02670757294311483
# Trained Epoch: 0 | Class Loss: 0.0746179296430005, Bounding loss: 0.025617153847125512
# Trained Epoch: 0 | Class Loss: 0.07420216838374151, Bounding loss: 0.024643073895448734
# Trained Epoch: 0 | Class Loss: 0.0742816227035122, Bounding loss: 0.023614252740114163
# Trained Epoch: 0 | Class Loss: 0.07426053342146113, Bounding loss: 0.022637428219395194
# Trained Epoch: 0 | Class Loss: 0.07407960275097118, Bounding loss: 0.02173892001371662
# Trained Epoch: 0 | Class Loss: 0.07407088205505097, Bounding loss: 0.020925074157005022
# Trained Epoch: 0 | Class Loss: 0.07389300052708966, Bounding loss: 0.02016470483855912
# Trained Epoch: 0 | Class Loss: 0.07361170140130338, Bounding loss: 0.019456066783795727
# Trained Epoch: 0 | Class Loss: 0.07339360785405129, Bounding loss: 0.018821351207724834
# Trained Epoch: 0 | Class Loss: 0.07315547466700557, Bounding loss: 0.01821415611828727
# Trained Epoch: 0 | Class Loss: 0.07277262609228348, Bounding loss: 0.017658457376065997
# Trained Epoch: 0 | Class Loss: 0.07233594055913664, Bounding loss: 0.01717346092700552
# Trained Epoch: 0 | Class Loss: 0.07191542230813051, Bounding loss: 0.016858470111141402
# Trained Epoch: 0 | Class Loss: 0.07169598477150918, Bounding loss: 0.016417488563895792
# Trained Epoch: 0 | Class Loss: 0.07128725300360367, Bounding loss: 0.016105940318823824
# Trained Epoch: 0 | Class Loss: 0.07095860867445802, Bounding loss: 0.015790607567820067
# Trained Epoch: 0 | Class Loss: 0.07078100156125634, Bounding loss: 0.015442441863482278
# Trained Epoch: 0 | Class Loss: 0.07042837002093444, Bounding loss: 0.015118543648359026
# Trained Epoch: 0 | Class Loss: 0.06996374106414047, Bounding loss: 0.01480383017382096
# Trained Epoch: 0 | Class Loss: 0.06948088447546112, Bounding loss: 0.014518307139351889
# Trained Epoch: 0 | Class Loss: 0.0689679751606279, Bounding loss: 0.01430127312055298
# Trained Epoch: 0 | Class Loss: 0.06863992713949066, Bounding loss: 0.01406584732977609
# Trained Epoch: 0 | Class Loss: 0.06834664853552348, Bounding loss: 0.013798315444447467
# Trained Epoch: 0 | Class Loss: 0.06783451595211934, Bounding loss: 0.013518151191514912
# Trained Epoch: 0 | Class Loss: 0.06732642447485652, Bounding loss: 0.01342333550802129
# Trained Epoch: 0 | Class Loss: 0.06723159389621398, Bounding loss: 0.01320719980045715
# Trained Epoch: 0 | Class Loss: 0.06718630611415986, Bounding loss: 0.013007905640085988
# Trained Epoch: 0 | Class Loss: 0.06723762471182253, Bounding loss: 0.01274098839380232
# Trained Epoch: 0 | Class Loss: 0.06712413072036925, Bounding loss: 0.012529303945129154
# Trained Epoch: 0 | Avg Classification Loss: 0.06690139262042939, Bounding loss: 0.012401575134186339
#
# Saved model to model_1.pth.
# Trained Epoch: 1 | Class Loss: 0.060002111848823876, Bounding loss: 0.0017386115230284323
# Trained Epoch: 1 | Class Loss: 0.05995874082425026, Bounding loss: 0.0015112640492593575
# Trained Epoch: 1 | Class Loss: 0.06092101590545385, Bounding loss: 0.0023824188240909915
# Trained Epoch: 1 | Class Loss: 0.059927287871888536, Bounding loss: 0.0020095187847405513
# Trained Epoch: 1 | Class Loss: 0.05971413169310514, Bounding loss: 0.0019454464164056961
# Trained Epoch: 1 | Class Loss: 0.05952085497910562, Bounding loss: 0.0021182987968594133
# Trained Epoch: 1 | Class Loss: 0.05765468637354907, Bounding loss: 0.0026279830373073113
# Trained Epoch: 1 | Class Loss: 0.058897429502996285, Bounding loss: 0.0030012000462438814
# Trained Epoch: 1 | Class Loss: 0.06019471780726798, Bounding loss: 0.0026676865784636098
# Trained Epoch: 1 | Class Loss: 0.06139143102453323, Bounding loss: 0.0024004464196342467
# Trained Epoch: 1 | Class Loss: 0.06273159814255486, Bounding loss: 0.0021818518281316365
# Trained Epoch: 1 | Class Loss: 0.06348326819978393, Bounding loss: 0.0019998027344914804
# Trained Epoch: 1 | Class Loss: 0.06371907948678465, Bounding loss: 0.0018457657474284066
# Trained Epoch: 1 | Class Loss: 0.0643863152893785, Bounding loss: 0.0017140220680177383
# Trained Epoch: 1 | Class Loss: 0.06480224666811119, Bounding loss: 0.0016002643342073355
# Trained Epoch: 1 | Class Loss: 0.06540665496723523, Bounding loss: 0.0015059198357346884
# Trained Epoch: 1 | Class Loss: 0.06524551966533644, Bounding loss: 0.0014276312095687672
# Trained Epoch: 1 | Class Loss: 0.06501352309857446, Bounding loss: 0.0018110344940840564
# Trained Epoch: 1 | Class Loss: 0.06483122365876985, Bounding loss: 0.0017802635513694187
# Trained Epoch: 1 | Class Loss: 0.06458883695453554, Bounding loss: 0.0018585458167701694
# Trained Epoch: 1 | Class Loss: 0.06417530476052609, Bounding loss: 0.0017964862626141701
# Trained Epoch: 1 | Class Loss: 0.06334671854474552, Bounding loss: 0.0020088719090076397
# Trained Epoch: 1 | Class Loss: 0.06289136395088557, Bounding loss: 0.002167138236259603
# Trained Epoch: 1 | Class Loss: 0.06303005602080267, Bounding loss: 0.0022976621307337157
# Trained Epoch: 1 | Class Loss: 0.0632520584908543, Bounding loss: 0.0022716592094828266
# Trained Epoch: 1 | Class Loss: 0.06349366362650433, Bounding loss: 0.002233690794859351
# Trained Epoch: 1 | Class Loss: 0.0636830623106295, Bounding loss: 0.0021680437817432055
# Trained Epoch: 1 | Class Loss: 0.06356631192292823, Bounding loss: 0.0022307011928474367
# Trained Epoch: 1 | Class Loss: 0.06373717144884945, Bounding loss: 0.002163745826326853
# Trained Epoch: 1 | Class Loss: 0.06370203195821948, Bounding loss: 0.0021833416264370894
# Trained Epoch: 1 | Class Loss: 0.06347128284314685, Bounding loss: 0.00225130193044248
# Trained Epoch: 1 | Class Loss: 0.06343479403087857, Bounding loss: 0.0023575798942351085
# Trained Epoch: 1 | Class Loss: 0.06341537494628068, Bounding loss: 0.0023830075115059248
# Trained Epoch: 1 | Class Loss: 0.06317971042988317, Bounding loss: 0.002421187016493816
# Trained Epoch: 1 | Class Loss: 0.06287737372142288, Bounding loss: 0.0025045348887269025
# Trained Epoch: 1 | Class Loss: 0.06240555522533723, Bounding loss: 0.0025348879078550823
# Trained Epoch: 1 | Class Loss: 0.062084302655736, Bounding loss: 0.002770330906058349
# Trained Epoch: 1 | Class Loss: 0.062062907089067795, Bounding loss: 0.0027441023635631483
# Trained Epoch: 1 | Class Loss: 0.0619318923158423, Bounding loss: 0.0027896506935441573
# Trained Epoch: 1 | Class Loss: 0.061607867300420956, Bounding loss: 0.0027942343042831968
# Trained Epoch: 1 | Class Loss: 0.0611507304380032, Bounding loss: 0.0029360517034646315
# Trained Epoch: 1 | Class Loss: 0.06093568013286153, Bounding loss: 0.0029858341283579056
# Trained Epoch: 1 | Class Loss: 0.060367683672877925, Bounding loss: 0.0029520646449474356
# Trained Epoch: 1 | Class Loss: 0.059668774940598655, Bounding loss: 0.0029388020875202956
# Trained Epoch: 1 | Class Loss: 0.05905341610880614, Bounding loss: 0.0029119198242483074
# Trained Epoch: 1 | Class Loss: 0.0584326018656273, Bounding loss: 0.0028623989016174577
# Trained Epoch: 1 | Class Loss: 0.05776039872065951, Bounding loss: 0.0029260262555309527
# Trained Epoch: 1 | Class Loss: 0.05712980894158738, Bounding loss: 0.0029399683644435004
# Trained Epoch: 1 | Class Loss: 0.0564223413511376, Bounding loss: 0.002943342205787957
# Trained Epoch: 1 | Class Loss: 0.055762098806698905, Bounding loss: 0.0029242593031225763
# Trained Epoch: 1 | Avg Classification Loss: 0.05574264908013865, Bounding loss: 0.0029237271691920333
#
# Saved model to model_2.pth.
# Trained Epoch: 2 | Class Loss: 0.01984036386925347, Bounding loss: 0.0030310439996058874
# Trained Epoch: 2 | Class Loss: 0.0223674958741123, Bounding loss: 0.004309109496748855
# Trained Epoch: 2 | Class Loss: 0.02168000796684783, Bounding loss: 0.004000325436889691
# Trained Epoch: 2 | Class Loss: 0.021830011257461868, Bounding loss: 0.0032438717951311508
# Trained Epoch: 2 | Class Loss: 0.021109863035717463, Bounding loss: 0.002771647924041042
# Trained Epoch: 2 | Class Loss: 0.020731569331662612, Bounding loss: 0.002526238032075364
# Trained Epoch: 2 | Class Loss: 0.020365903040602335, Bounding loss: 0.0022351143307275346
# Trained Epoch: 2 | Class Loss: 0.020383791737771946, Bounding loss: 0.002043700863146057
# Trained Epoch: 2 | Class Loss: 0.020340904961640892, Bounding loss: 0.0019751897452305253
# Trained Epoch: 2 | Class Loss: 0.020425720405363605, Bounding loss: 0.0020484003640009354
# Trained Epoch: 2 | Class Loss: 0.019716028035881305, Bounding loss: 0.002077269762543428
# Trained Epoch: 2 | Class Loss: 0.019412334331463655, Bounding loss: 0.0020412673837276367
# Trained Epoch: 2 | Class Loss: 0.01905899774229358, Bounding loss: 0.00212873030459034
# Trained Epoch: 2 | Class Loss: 0.018757162533883, Bounding loss: 0.002170649655629004
# Trained Epoch: 2 | Class Loss: 0.018534214549650686, Bounding loss: 0.0020721448727053647
# Trained Epoch: 2 | Class Loss: 0.018332418388872406, Bounding loss: 0.001989015349013602
# Trained Epoch: 2 | Class Loss: 0.0181008340853669, Bounding loss: 0.0018899016734279911
# Trained Epoch: 2 | Class Loss: 0.017859735879534287, Bounding loss: 0.0017990711377955878
# Trained Epoch: 2 | Class Loss: 0.017707753087196684, Bounding loss: 0.0017199290905088671
# Trained Epoch: 2 | Class Loss: 0.01736379836222625, Bounding loss: 0.0016472591425939456
# Trained Epoch: 2 | Class Loss: 0.017205391737949403, Bounding loss: 0.0015989609155423864
# Trained Epoch: 2 | Class Loss: 0.016940240441934647, Bounding loss: 0.0016382297633381181
# Trained Epoch: 2 | Class Loss: 0.01670558810534176, Bounding loss: 0.0016205396503541926
# Trained Epoch: 2 | Class Loss: 0.01644556579170158, Bounding loss: 0.001599841611376051
# Trained Epoch: 2 | Class Loss: 0.016295542676209453, Bounding loss: 0.0015590877078201417
# Trained Epoch: 2 | Class Loss: 0.016004794924122046, Bounding loss: 0.001522043945853495
# Trained Epoch: 2 | Class Loss: 0.015716228519731704, Bounding loss: 0.0014783749073076062
# Trained Epoch: 2 | Class Loss: 0.015493948612641077, Bounding loss: 0.0014545339235851325
# Trained Epoch: 2 | Class Loss: 0.015303953139686969, Bounding loss: 0.0014131838949475019
# Trained Epoch: 2 | Class Loss: 0.015073768740017875, Bounding loss: 0.0014120770137586414
# Trained Epoch: 2 | Class Loss: 0.014950504056250181, Bounding loss: 0.0013978962121934761
# Trained Epoch: 2 | Class Loss: 0.01467328034249601, Bounding loss: 0.0013615112683532061
# Trained Epoch: 2 | Class Loss: 0.014460257423710245, Bounding loss: 0.0013468680738830683
# Trained Epoch: 2 | Class Loss: 0.014336062366751463, Bounding loss: 0.0013719067966785645
# Trained Epoch: 2 | Class Loss: 0.014119160918987092, Bounding loss: 0.001362217598341561
# Trained Epoch: 2 | Class Loss: 0.013908223945746746, Bounding loss: 0.0013515495359257951
# Trained Epoch: 2 | Class Loss: 0.013722174853017088, Bounding loss: 0.0013685918285936366
# Trained Epoch: 2 | Class Loss: 0.013533609316621408, Bounding loss: 0.001366388397991895
# Trained Epoch: 2 | Class Loss: 0.013347250265069903, Bounding loss: 0.0013371768299342002
# Trained Epoch: 2 | Class Loss: 0.01321152088201706, Bounding loss: 0.0013081917391086554
# Trained Epoch: 2 | Class Loss: 0.013102567900872615, Bounding loss: 0.0012918639504532912
# Trained Epoch: 2 | Class Loss: 0.012962939186565383, Bounding loss: 0.0012726519933313318
# Trained Epoch: 2 | Class Loss: 0.012779656008790115, Bounding loss: 0.0012793666990103252
# Trained Epoch: 2 | Class Loss: 0.012661735609506185, Bounding loss: 0.0012748891299108683
# Trained Epoch: 2 | Class Loss: 0.012496152125611264, Bounding loss: 0.0012604521111812923
# Trained Epoch: 2 | Class Loss: 0.012372943772989826, Bounding loss: 0.0012471103126048334
# Trained Epoch: 2 | Class Loss: 0.01225787127734224, Bounding loss: 0.0012385481540495968
# Trained Epoch: 2 | Class Loss: 0.012181500904862582, Bounding loss: 0.0012514818419898269
# Trained Epoch: 2 | Class Loss: 0.012078484929261188, Bounding loss: 0.001266638617137252
# Trained Epoch: 2 | Class Loss: 0.011977754950940729, Bounding loss: 0.0012732251357165086
# Trained Epoch: 2 | Avg Classification Loss: 0.011975463644851697, Bounding loss: 0.0012727541215706679
#
# Saved model to model_3.pth.
# Trained Epoch: 3 | Class Loss: 0.006452607337803561, Bounding loss: 0.00013391999002532412
# Trained Epoch: 3 | Class Loss: 0.005089913692732219, Bounding loss: 0.0001222308496119003
# Trained Epoch: 3 | Class Loss: 0.005163068851673251, Bounding loss: 0.00039567434496684577
# Trained Epoch: 3 | Class Loss: 0.004893587726249065, Bounding loss: 0.000998773812118057
# Trained Epoch: 3 | Class Loss: 0.004545980436894781, Bounding loss: 0.0010633710576000261
# Trained Epoch: 3 | Class Loss: 0.004549286522346558, Bounding loss: 0.0011100371269771301
# Trained Epoch: 3 | Class Loss: 0.004475106994046384, Bounding loss: 0.000972505156384661
# Trained Epoch: 3 | Class Loss: 0.0045816282425741, Bounding loss: 0.0008578673278293278
# Trained Epoch: 3 | Class Loss: 0.004590889057331202, Bounding loss: 0.0007794352654378169
# Trained Epoch: 3 | Class Loss: 0.004664270643493392, Bounding loss: 0.0010597021203838806
# Trained Epoch: 3 | Class Loss: 0.004897061740639848, Bounding loss: 0.0012859595646239788
# Trained Epoch: 3 | Class Loss: 0.0051057067897869665, Bounding loss: 0.0012861077279329128
# Trained Epoch: 3 | Class Loss: 0.00555312532951477, Bounding loss: 0.001193251899740789
# Trained Epoch: 3 | Class Loss: 0.005561967229371349, Bounding loss: 0.001109831153808037
# Trained Epoch: 3 | Class Loss: 0.0055388104945678605, Bounding loss: 0.0010379573987066867
# Trained Epoch: 3 | Class Loss: 0.005558053702226746, Bounding loss: 0.0010479444766494012
# Trained Epoch: 3 | Class Loss: 0.0055370962982081336, Bounding loss: 0.0010287006837082812
# Trained Epoch: 3 | Class Loss: 0.005541392195285055, Bounding loss: 0.0009914654415345485
# Trained Epoch: 3 | Class Loss: 0.005671057609747506, Bounding loss: 0.0009806830457409614
# Trained Epoch: 3 | Class Loss: 0.005620448718414278, Bounding loss: 0.000936977840935213
# Trained Epoch: 3 | Class Loss: 0.0055823240843691415, Bounding loss: 0.000894754848839229
# Trained Epoch: 3 | Class Loss: 0.005466399121138367, Bounding loss: 0.0008605309008824135
# Trained Epoch: 3 | Class Loss: 0.0053782801871192845, Bounding loss: 0.0008244288332788491
# Trained Epoch: 3 | Class Loss: 0.005396499494435845, Bounding loss: 0.0007943906357778875
# Trained Epoch: 3 | Class Loss: 0.005417749238500332, Bounding loss: 0.0007724367141599169
# Trained Epoch: 3 | Class Loss: 0.00537936532994909, Bounding loss: 0.000756806138246407
# Trained Epoch: 3 | Class Loss: 0.005288039990054845, Bounding loss: 0.0007896541116390278
# Trained Epoch: 3 | Class Loss: 0.005303168640686436, Bounding loss: 0.0007724524690862728
# Trained Epoch: 3 | Class Loss: 0.005243010372649335, Bounding loss: 0.0007497872114079661
# Trained Epoch: 3 | Class Loss: 0.005200365374149479, Bounding loss: 0.0007285936825471297
# Trained Epoch: 3 | Class Loss: 0.005114683228952007, Bounding loss: 0.0007151026788173638
# Trained Epoch: 3 | Class Loss: 0.005090431057320709, Bounding loss: 0.0007065195810515597
# Trained Epoch: 3 | Class Loss: 0.00511303066701964, Bounding loss: 0.0007138258217616355
# Trained Epoch: 3 | Class Loss: 0.005101555963726224, Bounding loss: 0.0007016297084012425
# Trained Epoch: 3 | Class Loss: 0.005058930631642581, Bounding loss: 0.0006912687186695895
# Trained Epoch: 3 | Class Loss: 0.005025329142631929, Bounding loss: 0.0006809583204997827
# Trained Epoch: 3 | Class Loss: 0.004970458360170588, Bounding loss: 0.0006704532581617161
# Trained Epoch: 3 | Class Loss: 0.0049103356728725294, Bounding loss: 0.0006899173299053111
# Trained Epoch: 3 | Class Loss: 0.004859231644644072, Bounding loss: 0.0007030189743126664
# Trained Epoch: 3 | Class Loss: 0.004849083541817111, Bounding loss: 0.0006967673670931148
# Trained Epoch: 3 | Class Loss: 0.004866058940165383, Bounding loss: 0.0006871666014640941
# Trained Epoch: 3 | Class Loss: 0.004832676353393441, Bounding loss: 0.0006803897018276759
# Trained Epoch: 3 | Class Loss: 0.004799881741384652, Bounding loss: 0.0006701016127646359
# Trained Epoch: 3 | Class Loss: 0.004741423358554601, Bounding loss: 0.0006630750443452634
# Trained Epoch: 3 | Class Loss: 0.004767074417255064, Bounding loss: 0.0006555742921407152
# Trained Epoch: 3 | Class Loss: 0.004733186836286631, Bounding loss: 0.0006460523955357054
# Trained Epoch: 3 | Class Loss: 0.0047168594619518235, Bounding loss: 0.0006360857667943873
# Trained Epoch: 3 | Class Loss: 0.004674965094439958, Bounding loss: 0.0006279524018091799
# Trained Epoch: 3 | Class Loss: 0.004669029980002162, Bounding loss: 0.0006172912024487294
# Trained Epoch: 3 | Class Loss: 0.004665055356713465, Bounding loss: 0.0006104724578791376
# Trained Epoch: 3 | Avg Classification Loss: 0.004669836305975332, Bounding loss: 0.0006103170278023355
#
# Saved model to model_4.pth.

# %% [markdown]
# # 新段落

# %%
device = 'cpu'
model = ShapesModel()
model.load_state_dict(torch.load('model_4.pth', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Now let's visualize the predictions !
#
# The most exciting part of any neural network model setup. First let's visualize our ground truth.

# %%
sample, target = iter(valloader).next()
sample = torch.stack(sample,dim=0)

# %%
visDet(sample, target)

# %% [markdown]
# ### Our Model Predictions
#
# Note: We perform NMS upon our final predictions to clear up the output. This is done as a lot of anchors near to the actual object will fire resulting in a lot of boxes. NMS handles these multiple predictions by merging and giving a single box for a predicted object instead of multiple. This is best signified through another image:
#
# ![NMS](https://miro.medium.com/max/1000/0*WI5_K3bAbYaRyzE-.png)
#
# Now onto our model predictions !
#
# Your final task is to write code to visualize the model predictions on an image in the validation set. You can use the `visDet` function to help out with visualizing. Your main job would be to select what anchors (after applying offsets) to draw on the image. Generally, if the probability is > 0.7. It's a good idea to use the anchor. Also, you can use the `nms` function inside `boxes.py`.

# %%
def offset_inverse(anchors, offset):
  ex_box=[]
  for i in range(4):
    ex_boxes=torch.tensor([[0]*4]*192, device = device)

    gt_width = anchors[:, 2] - anchors[:, 0]
    gt_height = anchors[:, 3] - anchors[:, 1]
    gt_center_x = anchors[:, 0] + 0.5*gt_width
    gt_center_y = anchors[:, 1] + 0.5*gt_height

    ex_width=gt_width / (torch.exp(offset[i][:,2]))
    ex_height=gt_height / (torch.exp(offset[i][:,3]))
    ex_center_y=gt_center_y - offset[i][:,1]*ex_height
    ex_center_x=gt_center_x - offset[i][:,0]*ex_width

    ex_boxes[:, 0]=ex_center_x-0.5*ex_width
    ex_boxes[:, 1]=ex_center_y-0.5*ex_height
    ex_boxes[:, 2]=ex_boxes[:, 0]+ex_width
    ex_boxes[:, 3]=ex_boxes[:, 1]+ex_height

    ex_box.append(ex_boxes)
  return torch.stack(ex_box, dim=0)


def visPred(model, sample):
    #TODO: visualize your model predictions on the sample image.
    out_pred, offsets = model(sample)
    probability_trans = torch.nn.Sigmoid()
    out_pred = probability_trans(out_pred)

    pred_box = offset_inverse(gt_boxes, offsets)
    #print(pred_box.size())
 
    candidate_boxes = [pred_box[i][out_pred[i] > 0.7] for i in range(4)]
    candidate_cls = [out_pred[i][out_pred[i] > 0.7] for i in range(4)]

    indexs = []
    for i in range(4):
      indexs.append(nms(candidate_boxes[i].float(),candidate_cls[i].float(), iou_threshold=0.25))

    best_boxes = []
    for i in range(4):
      box_list = {'bounding_box': []}
      for index in indexs[i]:
        box_list['bounding_box'].append(candidate_boxes[i][index])
      best_boxes.append(box_list)
    print(best_boxes)
        
    # target: 4*N*4(x/y of points)
    visDet(sample, best_boxes)

visPred(model, sample)
# Out:
# [{'bounding_box': [tensor([ 26,  58,  85, 118]), tensor([ 75,  42, 134, 102])]}, {'bounding_box': [tensor([ 76,  42, 134, 103]), tensor([ 43,  10, 102,  70])]}, {'bounding_box': [tensor([14, -4, 70, 58]), tensor([ 76,  10, 134,  71]), tensor([ 72,  57, 133, 116])]}, {'bounding_box': [tensor([ 43,  74, 101, 134]), tensor([ 75,  -5, 134,  55]), tensor([11, 10, 69, 70])]}]

# %% [markdown]
# ## Conclusion
#
# Not bad, right ? This is a very barebones implementation and trained for a very short amount of epochs. However this is the meat and bones of most anchor based state of the art detectors out today. We can improve accuracy by doing multiscale training by incorporating a Feature Pyramid Network but that is for you to discover :')
#
# ## References
#
# Some foundational/good papers on object detection. This list is non exhaustive
#
# 1. [Single Shot Detector](https://arxiv.org/abs/1512.02325)
# 2. [YOLO](https://arxiv.org/abs/1612.08242)
# 3. [Faster RCNN](https://arxiv.org/abs/1506.01497)
# 4. [Feature Pyramid Network](https://arxiv.org/abs/1612.03144)
# 5. Bonus Read: [DETR- State of the art Object detector based on Transformers](https://arxiv.org/abs/2005.12872)
